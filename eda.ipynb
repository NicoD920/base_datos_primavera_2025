# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoD920/base_datos_primavera_2025/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Carga de Archivos

# %%
import pandas as pd

url_1 = "https://raw.githubusercontent.com/NicoD920/base_datos_primavera_2025/main/archivos/olist_customers_dataset.csv"
url_2 = "https://github.com/NicoD920/base_datos_primavera_2025/raw/refs/heads/main/archivos/olist_geolocation_dataset_simple.csv"
url_3 = "https://github.com/NicoD920/base_datos_primavera_2025/raw/refs/heads/main/archivos/olist_order_items_dataset.csv"
url_4 = "https://github.com/NicoD920/base_datos_primavera_2025/raw/refs/heads/main/archivos/olist_order_payments_dataset.csv"
url_5 = "https://github.com/NicoD920/base_datos_primavera_2025//raw/refs/heads/main/archivos/olist_order_reviews_dataset.csv"
url_6 = "https://github.com/NicoD920/base_datos_primavera_2025//raw/refs/heads/main/archivos/olist_orders_dataset.csv"
url_7 = "https://github.com/NicoD920/base_datos_primavera_2025//raw/refs/heads/main/archivos/olist_products_dataset.csv"
url_8 = "https://github.com/NicoD920/base_datos_primavera_2025//raw/refs/heads/main/archivos/olist_sellers_dataset.csv"
url_9 = "https://github.com/NicoD920/base_datos_primavera_2025//raw/refs/heads/main/archivos/product_category_name_translation.csv"

df_customers = pd.read_csv(url_1)
df_geolocation = pd.read_csv(url_2)
df_items = pd.read_csv(url_3)
df_payments = pd.read_csv(url_4)
df_reviews = pd.read_csv(url_5)
df_orders = pd.read_csv(url_6)
df_products = pd.read_csv(url_7)
df_sellers = pd.read_csv(url_8)
df_category = pd.read_csv(url_9)

print(df_customers.head())
print(df_geolocation.head())
print(df_items.head())
print(df_payments.head())
print(df_reviews.head())
print(df_orders.head())
print(df_products.head())
print(df_sellers.head())
print(df_category.head())
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#    geolocation_zip_code_prefix prioritized_city geolocation_state
# 0                         1037        sao paulo                SP
# ...

# %% [markdown]
# ## Nombre resultante:
# df_customers
#
# df_geolocation
#
# df_items
#
# df_payments
#
# df_reviews
#
# df_orders
#
# df_products
#
# df_sellers
#
# df_translation

# %% [markdown]
# ## Analizamos customers

# %%
df_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
df_customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# No se observan problemas aparentes en esta base

# %% [markdown]
# ## Analizamos geolocation

# %%
df_geolocation.head()
# Out:
#    geolocation_zip_code_prefix prioritized_city geolocation_state
# 0                         1037        sao paulo                SP
# 1                         1046        sao paulo                SP
# 2                         1041        sao paulo                SP
# 3                         1035        sao paulo                SP
# 4                         1012        sao paulo                SP

# %%
df_geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19023 entries, 0 to 19022
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   geolocation_zip_code_prefix  19023 non-null  int64
#  1   prioritized_city             19023 non-null  object
#  2   geolocation_state            19023 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 446.0+ KB

# %%
df_geolocation.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# prioritized_city               0
# geolocation_state              0
# dtype: int64

# %% [markdown]
# No se observan problemas aparentes

# %% [markdown]
# ## Analizamos items

# %%
df_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
df_items.describe().T
# Out:
#                   count        mean         std   min    25%    50%     75%  \
# order_item_id  112650.0    1.197834    0.705124  1.00   1.00   1.00    1.00
# price          112650.0  120.653739  183.633928  0.85  39.90  74.99  134.90
# freight_value  112650.0   19.990320   15.806405  0.00  13.08  16.26   21.15
#
#                    max
# order_item_id    21.00
# price          6735.00
# freight_value   409.68

# %%
df_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# No se observan problemas aparentes

# %% [markdown]
# ## Analizamos payments

# %%
df_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
df_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
df_payments.describe().T
# Out:
#                          count        mean         std  min    25%    50%  \
# payment_sequential    103886.0    1.092679    0.706584  1.0   1.00    1.0
# payment_installments  103886.0    2.853349    2.687051  0.0   1.00    1.0
# payment_value         103886.0  154.100380  217.494064  0.0  56.79  100.0
#
#                            75%       max
# payment_sequential      1.0000     29.00
# payment_installments    4.0000     24.00
# payment_value         171.8375  13664.08

# %%
df_payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %% [markdown]
# No se observan problemas aparentes

# %% [markdown]
# ## Analizamos reviews

# %%
df_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
df_reviews.describe().T
# Out:
#                 count      mean       std  min  25%  50%  75%  max
# review_score  99224.0  4.086421  1.347579  1.0  4.0  5.0  5.0  5.0

# %%
df_reviews.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
df_reviews.isna().sum() / df_reviews.shape[0]
# Out:
# review_id                  0.000000
# order_id                   0.000000
# review_score               0.000000
# review_comment_title       0.883415
# review_comment_message     0.587025
# review_creation_date       0.000000
# review_answer_timestamp    0.000000
# dtype: float64

# %% [markdown]
# Eliminamos los registros con nulos dado que la cantidad es muy grande

# %%
df_reviews = df_reviews.drop(columns=['review_comment_title', 'review_comment_message'])
display(df_reviews.head())
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_creation_date review_answer_timestamp
# 0             4  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1             5  2018-03-10 00:00:00     2018-03-11 03:05:13
# 2             5  2018-02-17 00:00:00     2018-02-18 14:36:24
# 3             5  2017-04-21 00:00:00     2017-04-21 22:02:06
# 4             5  2018-03-01 00:00:00     2018-03-02 10:26:53

# %% [markdown]
# ## Analizamos orders

# %%
df_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df_orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Convert timestamp columns to datetime objects
df_orders['order_purchase_timestamp'] = pd.to_datetime(df_orders['order_purchase_timestamp'])
df_orders['order_approved_at'] = pd.to_datetime(df_orders['order_approved_at'])
df_orders['order_delivered_carrier_date'] = pd.to_datetime(df_orders['order_delivered_carrier_date'])
df_orders['order_delivered_customer_date'] = pd.to_datetime(df_orders['order_delivered_customer_date'])
df_orders['order_estimated_delivery_date'] = pd.to_datetime(df_orders['order_estimated_delivery_date'])


# Calculate time differences
time_diff_purchase_approved = (df_orders['order_approved_at'] - df_orders['order_purchase_timestamp']).dt.total_seconds() / (60*60*24) # in days
time_diff_approved_carrier = (df_orders['order_delivered_carrier_date'] - df_orders['order_approved_at']).dt.total_seconds() / (60*60*24) # in days
time_diff_carrier_customer = (df_orders['order_delivered_customer_date'] - df_orders['order_delivered_carrier_date']).dt.total_seconds() / (60*60*24) # in days

fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(12, 15))

sns.histplot(data=time_diff_purchase_approved.dropna(), ax=axes[0], kde=True, bins=50)
axes[0].set_title('Distribution of Time between Purchase and Approval (Days)')
axes[0].set_xlabel('Time Difference (Days)')


sns.histplot(data=time_diff_approved_carrier.dropna(), ax=axes[1], kde=True, bins=50)
axes[1].set_title('Distribution of Time between Approval and Carrier Handover (Days)')
axes[1].set_xlabel('Time Difference (Days)')


sns.histplot(data=time_diff_carrier_customer.dropna(), ax=axes[2], kde=True, bins=50)
axes[2].set_title('Distribution of Time between Carrier Handover and Customer Delivery (Days)')
axes[2].set_xlabel('Time Difference (Days)')


plt.tight_layout()
plt.show()

# %%
df_orders.isnull().sum() / df_orders.shape[0]
# Out:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.001609
# order_delivered_carrier_date     0.017930
# order_delivered_customer_date    0.029817
# order_estimated_delivery_date    0.000000
# dtype: float64

# %%
# Convert timestamp columns to datetime objects
df_orders['order_purchase_timestamp'] = pd.to_datetime(df_orders['order_purchase_timestamp'])
df_orders['order_approved_at'] = pd.to_datetime(df_orders['order_approved_at'])
df_orders['order_delivered_carrier_date'] = pd.to_datetime(df_orders['order_delivered_carrier_date'])
df_orders['order_delivered_customer_date'] = pd.to_datetime(df_orders['order_delivered_customer_date'])
df_orders['order_estimated_delivery_date'] = pd.to_datetime(df_orders['order_estimated_delivery_date'])

# Calculate time differences
time_diff_purchase_approved = df_orders['order_approved_at'] - df_orders['order_purchase_timestamp']
time_diff_approved_carrier = df_orders['order_delivered_carrier_date'] - df_orders['order_approved_at']
time_diff_carrier_customer = df_orders['order_delivered_customer_date'] - df_orders['order_delivered_carrier_date']
time_diff_customer_estimated = df_orders['order_estimated_delivery_date'] - df_orders['order_delivered_customer_date']

# Calculate average time differences
avg_time_purchase_approved = time_diff_purchase_approved.mean()
avg_time_approved_carrier = time_diff_approved_carrier.mean()
avg_time_carrier_customer = time_diff_carrier_customer.mean()
avg_time_customer_estimated = time_diff_customer_estimated.mean()

print(f"Average time between purchase and approval: {avg_time_purchase_approved}")
print(f"Average time between approval and carrier handover: {avg_time_approved_carrier}")
print(f"Average time between carrier handover and customer delivery: {avg_time_carrier_customer}")
print(f"Average time between customer delivery and estimated delivery: {avg_time_customer_estimated}")
# Out:
# Average time between purchase and approval: 0 days 10:25:08.739486910
# Average time between approval and carrier handover: 2 days 19:19:15.298850927
# Average time between carrier handover and customer delivery: 9 days 07:55:59.254148743
# Average time between customer delivery and estimated delivery: 11 days 04:17:55.957616402

# %%
# Impute missing 'order_approved_at' using average time from 'order_purchase_timestamp'
df_orders['order_approved_at'].fillna(df_orders['order_purchase_timestamp'] + avg_time_purchase_approved, inplace=True)

# Impute missing 'order_delivered_carrier_date' using average time from 'order_approved_at'
df_orders['order_delivered_carrier_date'].fillna(df_orders['order_approved_at'] + avg_time_approved_carrier, inplace=True)

# Impute missing 'order_delivered_customer_date' using average time from 'order_delivered_carrier_date'
df_orders['order_delivered_customer_date'].fillna(df_orders['order_delivered_carrier_date'] + avg_time_carrier_customer, inplace=True)

print("Missing values after imputation:")
print(df_orders.isnull().sum())
# Out:
# /tmp/ipython-input-2496640956.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_orders['order_approved_at'].fillna(df_orders['order_purchase_timestamp'] + avg_time_purchase_approved, inplace=True)
# /tmp/ipython-input-2496640956.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_orders.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Convert timestamp columns to datetime objects (if not already done)
df_orders['order_purchase_timestamp'] = pd.to_datetime(df_orders['order_purchase_timestamp'])
df_orders['order_approved_at'] = pd.to_datetime(df_orders['order_approved_at'])
df_orders['order_delivered_carrier_date'] = pd.to_datetime(df_orders['order_delivered_carrier_date'])
df_orders['order_delivered_customer_date'] = pd.to_datetime(df_orders['order_delivered_customer_date'])
df_orders['order_estimated_delivery_date'] = pd.to_datetime(df_orders['order_estimated_delivery_date'])

# Calculate time differences in days
time_diff_purchase_approved = (df_orders['order_approved_at'] - df_orders['order_purchase_timestamp']).dt.total_seconds() / (60*60*24)
time_diff_approved_carrier = (df_orders['order_delivered_carrier_date'] - df_orders['order_approved_at']).dt.total_seconds() / (60*60*24)
time_diff_carrier_customer = (df_orders['order_delivered_customer_date'] - df_orders['order_delivered_carrier_date']).dt.total_seconds() / (60*60*24)

fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(12, 15))

sns.histplot(data=time_diff_purchase_approved.dropna(), ax=axes[0], kde=True, bins=50)
axes[0].set_title('Distribution of Time between Purchase and Approval (Days)')
axes[0].set_xlabel('Time Difference (Days)')

sns.histplot(data=time_diff_approved_carrier.dropna(), ax=axes[1], kde=True, bins=50)
axes[1].set_title('Distribution of Time between Approval and Carrier Handover (Days)')
axes[1].set_xlabel('Time Difference (Days)')

sns.histplot(data=time_diff_carrier_customer.dropna(), ax=axes[2], kde=True, bins=50)
axes[2].set_title('Distribution of Time between Carrier Handover and Customer Delivery (Days)')
axes[2].set_xlabel('Time Difference (Days)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Rellenamos usando el tiempo de diferencia promedio, para no cambiar la distribución

# %% [markdown]
# ## Analizamos products

# %%
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
df_products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
df_products.isnull().sum() / df_products.shape[0]
# Out:
# product_id                    0.000000
# product_category_name         0.018512
# product_name_lenght           0.018512
# product_description_lenght    0.018512
# product_photos_qty            0.018512
# product_weight_g              0.000061
# product_length_cm             0.000061
# product_height_cm             0.000061
# product_width_cm              0.000061
# dtype: float64

# %%
# Filter rows with any null values
null_rows = df_products[df_products.isnull().any(axis=1)]

# Display the first 10 rows with null values
display(null_rows.head(10))
# Out:
#                            product_id product_category_name  \
# 105  a41e356c76fab66334f36de622ecbd3a                   NaN
# 128  d8dee61c2034d6d075997acef1870e9b                   NaN
# 145  56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154  46b48281eb6d663ced748f324108c733                   NaN
# 197  5fb61f482620cb672f5e586bb132eae9                   NaN
# 244  e10758160da97891c2fdcbc35f0f031d                   NaN
# 294  39e3b9b12cd0bf8ee681bbc1c130feb5                   NaN
# 299  794de06c32a626a5692ff50e4985d36f                   NaN
# 347  7af3e2da474486a3519b0cba9dea8ad9                   NaN
# 428  629beb8e7317703dcc5f35b5463fd20e                   NaN
#
#      product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                  NaN                         NaN                 NaN
# 128                  NaN                         NaN                 NaN
# 145                  NaN                         NaN                 NaN
# ...

# %%
print(f"Number of rows with null values in df_products: {null_rows.shape[0]}")
# Out:
# Number of rows with null values in df_products: 611

# %%
product_ids_with_nulls = df_products[df_products.isnull().any(axis=1)]['product_id'].tolist()

# print("List of product_ids with null values:")
# print(product_ids_with_nulls)
# Out:
# List of product_ids with null values:
# ...

# %%
df_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
# Filter df_items to get orders with products from the list of null product_ids
orders_with_null_products = df_items[df_items['product_id'].isin(product_ids_with_nulls)]

# Count the number of unique order_ids in the filtered dataframe
num_orders_with_null_products = orders_with_null_products['order_id'].nunique()

print(f"Number of orders with products that have null values: {num_orders_with_null_products}")
# Out:
# Number of orders with products that have null values: 1452

# %%
# Calculate the total number of unique orders
total_orders = df_orders['order_id'].nunique()

# Calculate the percentage of orders with null products
percentage_orders_with_null_products = (num_orders_with_null_products / total_orders) * 100

print(f"Percentage of orders with products that have null values: {percentage_orders_with_null_products:.2f}%")
# Out:
# Percentage of orders with products that have null values: 1.46%

# %% [markdown]
# Podemos eliminar los registros quee están nulos y solo afectarían a un 1,.46% de los datos de orders

# %% [markdown]
# ## Analizamos sellers

# %%
df_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
df_sellers.describe().T
# Out:
#                          count          mean          std     min     25%  \
# seller_zip_code_prefix  3095.0  32291.059451  32713.45383  1001.0  7093.5
#
#                             50%      75%      max
# seller_zip_code_prefix  14940.0  64552.5  99730.0

# %%
df_sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %% [markdown]
# ## Analizamos category

# %%
df_category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
df_category.describe().T
# Out:
#                               count unique            top freq
# product_category_name            71     71   beleza_saude    1
# product_category_name_english    71     71  health_beauty    1

# %%
df_category.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64
